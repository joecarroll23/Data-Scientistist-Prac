# %%
import sklearn

# %%
from sklearn.datasets import load_iris

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as num

# %%
data = load_iris()

# %%
iris_df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
iris_df[iris_df['species'] == 'setosa'].describe()
#The Initial Describition shows that on average Setosais the shortest in all categories except for sepal width
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count           50.00000         50.000000          50.000000
# mean             5.00600          3.428000           1.462000
# std              0.35249          0.379064           0.173664
# min              4.30000          2.300000           1.000000
# 25%              4.80000          3.200000           1.400000
# 50%              5.00000          3.400000           1.500000
# 75%              5.20000          3.675000           1.575000
# max              5.80000          4.400000           1.900000
#
#        petal width (cm)
# count         50.000000
# mean           0.246000
# std            0.105386
# min            0.100000
# 25%            0.200000
# 50%            0.200000
# 75%            0.300000
# max            0.600000

# %%
iris_df[iris_df['species'] == 'versicolor'].describe()
#The Initial Description shows that Veriscolor is 1st for each category except for width in whih it is 2nd
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          50.000000         50.000000          50.000000
# mean            5.936000          2.770000           4.260000
# std             0.516171          0.313798           0.469911
# min             4.900000          2.000000           3.000000
# 25%             5.600000          2.525000           4.000000
# 50%             5.900000          2.800000           4.350000
# 75%             6.300000          3.000000           4.600000
# max             7.000000          3.400000           5.100000
#
#        petal width (cm)
# count         50.000000
# mean           1.326000
# std            0.197753
# min            1.000000
# 25%            1.200000
# 50%            1.300000
# 75%            1.500000
# max            1.800000

# %%
iris_df[iris_df['species'] == 'virginica'].describe()
#The Initial Description shows that Virginica is 2nd for each category except for width in whih it is smallest")
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count           50.00000         50.000000          50.000000
# mean             6.58800          2.974000           5.552000
# std              0.63588          0.322497           0.551895
# min              4.90000          2.200000           4.500000
# 25%              6.22500          2.800000           5.100000
# 50%              6.50000          3.000000           5.550000
# 75%              6.90000          3.175000           5.875000
# max              7.90000          3.800000           6.900000
#
#        petal width (cm)
# count          50.00000
# mean            2.02600
# std             0.27465
# min             1.40000
# 25%             1.80000
# 50%             2.00000
# 75%             2.30000
# max             2.50000

# %%
iris_df['species'] = data.target_names[data.target]

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
plt.figure(figsize=(8, 6))
for species, color in zip(data.target_names, ['blue', 'green', 'red']):
    plt.scatter(iris_df[iris_df['species'] == species]['sepal length (cm)'],
                iris_df[iris_df['species'] == species]['sepal width (cm)'],
                c=color, label=species, alpha=0.8, edgecolors='w')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Scatter Plot: Sepal Length vs. Sepal Width')
plt.legend()
plt.grid(True)
sepal_len_v_width_sp = """
 Setosa has shorter sepal length and wider sepal width
Versicolor has moderate sepal length and sepal width
Virginica  has longer sepal lengths but thinder speal widths
There is some overlapping between Versicolor and Virginica
"""
plt.text(10, 3, sepal_len_v_width_sp, fontsize=10, bbox=dict(facecolor='lightgray', alpha=0.5))

plt.show()

# %%
plt.figure(figsize=(8, 6))
for species, color in zip(data.target_names, ['blue', 'green', 'red']):
    plt.scatter(iris_df[iris_df['species'] == species]['petal length (cm)'],
                iris_df[iris_df['species'] == species]['petal width (cm)'],
                c=color, label=species, alpha=0.8, edgecolors='w')
plt.xlabel('Petal Length in cm')
plt.ylabel('Petal Width in cm')
plt.title('Scatter Plot of  Petal Length and Petal Width')
plt.legend()
plt.grid(True)
petal_len_v_width_sp = """
Setosa has shortest width and length but their ratio is the highest
Versicolor is moderate in terms of width of length
Virginica has the longest petal and is also widest

There is minimal overlap in this model and each group is clearly defined
"""
plt.text(10, 3, sepal_len_v_width_sp, fontsize=10, bbox=dict(facecolor='lightgray', alpha=0.5))

plt.show()

# %%
sns.boxplot(x = 'species', y = 'sepal length (cm)', data = iris_df)
# Out:
# <Axes: xlabel='species', ylabel='sepal length (cm)'>

# %%
sns.boxplot(x = 'species', y = 'sepal width (cm)', data = iris_df)
# Out:
# <Axes: xlabel='species', ylabel='sepal width (cm)'>

# %%
sns.boxplot(x = 'species', y = 'petal length (cm)', data = iris_df)
# Out:
# <Axes: xlabel='species', ylabel='petal length (cm)'>

# %%
sns.boxplot(x = 'species', y = 'petal width (cm)', data = iris_df)
# Out:
# <Axes: xlabel='species', ylabel='petal width (cm)'>

# %%
plt.hist(iris_df[iris_df['species'] == 'virginica']['sepal length (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.hist(iris_df[iris_df['species'] == 'setosa']['sepal length (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.hist(iris_df[iris_df['species'] == 'versicolor']['sepal length (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.title('Sepal Length by Species')
plt.xlabel('Sepal Length in  cm')
plt.ylabel('Frequency')
plt.legend(title='Species', labels=['Virginica', 'Setosa', 'Versicolor'])
plt.text(7.5, -5, "The Histogram shows that the Virginica Specie has the Longest Length with the highest frequency and the Setosa Specie has the shortest with the highest Frequency", ha='center', fontsize=10)
plt.show()

# %%
plt.hist(iris_df[iris_df['species'] == 'virginica']['sepal width (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.hist(iris_df[iris_df['species'] == 'setosa']['sepal width (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.hist(iris_df[iris_df['species'] == 'versicolor']['sepal width (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.title('Sepal Width by Species')
plt.xlabel('Sepal Width in  cm')
plt.ylabel('Frequency')
plt.legend(title='Species', labels=['Virginica', 'Setosa', 'Versicolor'])
plt.text(7.5, -5, "Virginica: The sepal length distribution for the 'Virginica' species.", ha='center', fontsize=10)
plt.show()

# %%
plt.hist(iris_df[iris_df['species'] == 'virginica']['petal length (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.hist(iris_df[iris_df['species'] == 'setosa']['petal length (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.hist(iris_df[iris_df['species'] == 'versicolor']['petal length (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.title('Petal Length by Species')
plt.xlabel('Petal Length in  cm')
plt.ylabel('Frequency')
plt.legend(title='Species', labels=['Virginica', 'Setosa', 'Versicolor'])
plt.show()

# %%
plt.hist(iris_df[iris_df['species'] == 'virginica']['petal width (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.hist(iris_df[iris_df['species'] == 'setosa']['petal width (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.hist(iris_df[iris_df['species'] == 'versicolor']['petal width (cm)'] , bins=10, edgecolor='black',alpha=0.5,)
plt.title('Petal Width by Species')
plt.xlabel('Petal Width in  cm')
plt.ylabel('Frequency')
plt.legend(title='Species', labels=['Virginica', 'Setosa', 'Versicolor'])
plt.show()

# %%
sns.violinplot(x='species', y='petal length (cm)', data=iris_df)
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.title('Violin Plot of Petal Length by Species')
plt.show()

# %%
sns.violinplot(x='species', y='petal length (cm)', data=iris_df)
plt.xlabel('Species')
plt.ylabel('Petal Width (cm)')
plt.title('Violin Plot of Petal Width by Species')
plt.show()

# %%
sns.violinplot(x='species', y='petal length (cm)', data=iris_df)
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.title('Violin Plot of Sepal Length by Species')
plt.show()

# %%
sns.violinplot(x='species', y='petal length (cm)', data=iris_df)
plt.xlabel('Species')
plt.ylabel('Sepal Width (cm)')
plt.title('Violin Plot of Sepal Width by Species')
plt.show()

# %%
sns.kdeplot(data=iris_df, x='sepal length (cm)', hue='species', fill=True, common_norm=False)
plt.title('Density Plot of Sepal Length (cm) by Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Density')
plt.legend(title='Species', labels=['Virginica', 'Setosa', 'Versicolor'])
plt.show()
